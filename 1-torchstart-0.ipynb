# %%
# %run ./installers

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
scalar = torch.tensor(7)

# %%
scalar.ndim

# %%
scalar.item()

# %%
vector = torch.tensor([1, 2])

# %%
vector.ndim

# %%
vector.shape

# %%
MATRIX = torch.tensor(([[1, 3]]))

# %%
MATRIX
